# %%
# !apt install lshw
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   pci.ids usb.ids
# The following NEW packages will be installed:
#   lshw pci.ids usb.ids
# 0 upgraded, 3 newly installed, 0 to remove and 29 not upgraded.
# Need to get 790 kB of archives.
# After this operation, 2,988 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 lshw amd64 02.19.git.2021.06.19.996aaad9c7-2build1 [321 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 pci.ids all 0.0~2022.01.22-1 [251 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb.ids all 2022.04.02-1 [219 kB]
# Fetched 790 kB in 1s (613 kB/s)
# Selecting previously unselected package lshw.
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../lshw_02.19.git.2021.06.19.996aaad9c7-2build1_amd64.deb ...
# ...

# %%
# !export OLLAMA_DEBUG='true'

# %%
# !nohup ollama serve &> /dev/null &

# %%
# !ollama pull llama3.1
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏  20 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   2% ▕▏  89 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   3% ▕▏ 124 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   3% ▕▏ 155 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   4% ▕▏ 173 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   4% ▕▏ 219 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   5% ▕▏ 232 MB/4.9 GB                  pulling manifest
# ...

# %%
# !git clone https://github.com/saintclairlima/assistente-busca.git
# !git fetch --all
# %cd /content/assistente-busca
# !python -m venv chat-env
# !source chat-env/bin/activate
# !chmod 777 setup.sh
# !./setup.sh
# Out:
# Cloning into 'assistente-busca'...
# remote: Enumerating objects: 1618, done.
# remote: Counting objects: 100% (366/366), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 1618 (delta 292), reused 253 (delta 197), pack-reused 1252 (from 3)
# Receiving objects: 100% (1618/1618), 128.78 MiB | 20.50 MiB/s, done.
# Resolving deltas: 100% (1131/1131), done.
# fatal: not a git repository (or any of the parent directories): .git
# /content/assistente-busca
# Error: Command '['/content/assistente-busca/chat-env/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# /bin/bash: line 1: chat-env/bin/activate: No such file or directory
# Preparando os arquivos necessários...
# Archive:  api/dados/bancos_vetores/bancos_vetores.zip
#    creating: api/dados/bancos_vetores/banco_assistente/
#    creating: api/dados/bancos_vetores/banco_assistente/023ce53d-8006-4cfe-9a05-8d564372bfd2/
# ...

# %%
# !pip install pyngrok
from pyngrok import ngrok

# %%
ngrok.set_auth_token("")

# %%
conexao = ngrok.connect(8000)

# %%
print(f"{conexao.public_url}/chat?url_redirec={conexao.public_url}")
# Out:
# https://bc6e-34-16-179-158.ngrok-free.app/chat?url_redirec=https://bc6e-34-16-179-158.ngrok-free.app

# %%
# !uvicorn api.api:controller --reload
#!uvicorn api.api:controller --reload &> /dev/null &
# Out:
# INFO:     Will watch for changes in these directories: ['/content/assistente-busca']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [3688] using WatchFiles
# Inicializando a estrutura da API...
# Importando as bibliotecas...
# 2025-03-30 19:51:29.942219: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743364290.214978    3690 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743364290.291896    3690 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7 (delta 5), reused 7 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 746 bytes | 248.00 KiB/s, done.
# From https://github.com/saintclairlima/assistente-busca
#    14bbf0d..df9e1a4  main       -> origin/main
#    24e9b82..4a0a892  parse-json -> origin/parse-json
# Updating 14bbf0d..df9e1a4
# Fast-forward
#  api/dados/persistencia.py | 5 ++++-
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
# !nohup ollama serve &> /dev/null &

# %%
# !python -m api.dados.persistencia
# Out:
# Criando banco SQL com documentos do banco vetorial (api/dados/bancos_vetores/banco_assistente)
# -- criando tabelas
# Inicializando banco (sqlite) api/dados/persistencia.db usando api/dados/scripts_geracao_sqlite.sql
# Dados persistidos em api/dados/persistencia.db
# -- salvando coleções
# Coleção documentos_rh salva em api/dados/persistencia.db com id 1
# Coleção documentos_rh_openai salva em api/dados/persistencia.db com id 1
# -- salvando documentos
# Banco SQL concluído.
